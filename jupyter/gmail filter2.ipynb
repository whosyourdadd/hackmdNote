# %%
! pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib
# Out:
# Requirement already satisfied: google-api-python-client in /opt/homebrew/lib/python3.11/site-packages (2.99.0)
# Requirement already satisfied: google-auth-httplib2 in /opt/homebrew/lib/python3.11/site-packages (0.1.1)
# Requirement already satisfied: google-auth-oauthlib in /opt/homebrew/lib/python3.11/site-packages (1.1.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.15.0 in /opt/homebrew/lib/python3.11/site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in /opt/homebrew/lib/python3.11/site-packages (from google-api-python-client) (2.23.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /opt/homebrew/lib/python3.11/site-packages (from google-api-python-client) (2.11.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /opt/homebrew/lib/python3.11/site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/homebrew/lib/python3.11/site-packages (from google-auth-oauthlib) (1.3.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /opt/homebrew/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.60.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /opt/homebrew/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (4.21.12)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /opt/homebrew/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/homebrew/lib/python3.11/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/homebrew/lib/python3.11/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: urllib3<2.0 in /opt/homebrew/lib/python3.11/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (1.26.16)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /opt/homebrew/lib/python3.11/site-packages (from httplib2<1.dev0,>=0.15.0->google-api-python-client) (3.1.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/homebrew/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/homebrew/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2023.7.22)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
from __future__ import print_function

import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

import dateutil.parser as parser
from bs4 import BeautifulSoup

# %%
SCOPES = ['https://mail.google.com/','https://www.googleapis.com/auth/gmail.modify']

creds = None
# The file token.json stores the user's access and refresh tokens, and is
# created automatically when the authorization flow completes for the first
# time.
if os.path.exists('token.json'):
    creds = Credentials.from_authorized_user_file('token.json', SCOPES)
# If there are no (valid) credentials available, let the user log in.
if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
        creds.refresh(Request())
    else:
        flow = InstalledAppFlow.from_client_secrets_file('credentials.json', SCOPES)
        creds = flow.run_local_server(port=0)
        # Save the credentials for the next run
    with open('token.json', 'w') as token:
        token.write(creds.to_json())


#label_id_one = 'UNREAD'
label_id_one = 'INBOX'
label_id_one = 'CATEGORY_UPDATES'
service = build('gmail', 'v1', credentials=creds)
unread_msgs = service.users().messages().list(userId='me',labelIds=[label_id_one]).execute()
mssg_list = unread_msgs['messages']
print("get '"+label_id_one + "' list")
# Out:
# get 'CATEGORY_UPDATES' list

# %%
final_list = [ ]    
for mssg in mssg_list:
    temp_dict = { }
    m_id = mssg['id'] # get id of individual message
    message = service.users().messages().get(userId='me', id=m_id).execute() # fetch the message using API
    payld = message['payload'] # get payload of the message 
    headr = payld['headers'] # get header of the payload
    for header in headr:
        name = header['name']
        value = header['value']
        
        if name == 'From':
            temp_dict['Sender'] = value
        elif name == 'Subject':
            temp_dict['Subject'] = value
        elif name == 'Date':
            date_parse = parser.parse(value)
            m_date = date_parse.date()
            temp_dict['Date'] = str(m_date)
        temp_dict['msg_id'] = m_id
        '''
        try:
            # Fetching message body
            mssg_parts = payld['parts'] # fetching the message parts
            part_one  = mssg_parts[0] # fetching first element of the part 
            part_body = part_one['body'] # fetching body of the message
            part_data = part_body['data'] # fetching data from the body
            clean_one = part_data.replace("-","+") # decoding from Base64 to UTF-8
            clean_one = clean_one.replace("_","/") # decoding from Base64 to UTF-8
            clean_two = base64.b64decode (bytes(clean_one, 'UTF-8')) # decoding from Base64 to UTF-8
            soup = BeautifulSoup(clean_two , "lxml" )
            mssg_body = soup.body()
            # mssg_body is a readible form of message body
            # depending on the end user's requirements, it can be further cleaned 
            # using regex, beautiful soup, or any other method
            temp_dict['Message_body'] = mssg_body
        except :
            pass'''
        
    final_list.append(temp_dict)
print ("temp_dict strlen: ", str(len(final_list)))
# Out:
# temp_dict strlen:  100

# %%
final_list
# Out:
# [{'msg_id': '18a9cc017e75b4c4',
#   'Date': '2023-09-16',
#   'Subject': '安全性快訊',
#   'Sender': 'Google <no-reply@accounts.google.com>'},
#  {'msg_id': '18a9c1a8d62018cf',
#   'Date': '2023-09-16',
#   'Subject': '安全性快訊',
#   'Sender': 'Google <no-reply@accounts.google.com>'},
#  {'msg_id': '18a9b7763ddf0aed',
#   'Date': '2023-09-15',
#   'Sender': 'epassbook@tdcc.com.tw',
#   'Subject': '集保e手掌握銀行資訊更新次數彙整通知'},
#  {'msg_id': '18a9b6841a5e62a3',
#   'Date': '2023-09-16',
#   'Sender': '"台北富邦行動銀行" <mbank@dfm.taipeifubon.com.tw>',
#   'Subject': '台北富邦行動銀行一般登入交易「成功」通知'},
#  {'msg_id': '18a9b673b09df092',
#   'Date': '2023-09-16',
#   'Sender': 'Apple <News@insideapple.apple.com>',
#   'Subject': '<AD> 立即預訂 iPhone 15 Pro 與 iPhone 15。'},
#  {'msg_id': '18a9b018a39a5849',
#   'Date': '2023-09-16',
#   'Sender': '"玉山銀行" <Service@info.esunbank.com>',
#   'Subject': '玉山網路銀行每日帳務訊息通知'},
#  {'msg_id': '18a9933066bc15e1',
#   'Subject': '【課程即將上線】填問卷領 500 元課程折扣券，體驗會好評達 4.9 顆星🔥',
#   'Sender': '"富果團隊" <service@fugle.tw>',
#   'Date': '2023-09-15'},
#  {'msg_id': '18a9925ecae4b8bc',
#   'Date': '2023-09-15',
#   'Sender': 'Firstrade Securities <service@firstrade.com>',
#   'Subject': 'Top Options Trading Ideas for the Coming Week'},
#  {'msg_id': '18a98c823441b66b',
#   'Date': '2023-09-15',
#   'Subject': '【MM團隊來信】湯傑策，和你分享M平方里程碑，送上一份專屬禮物 🎁',
#   'Sender': '"MacroMicro.me 財經M平方" <web@mg.macromicro.me>'},
#  {'msg_id': '18a97bc314d50f9c',
#   'Date': '2023-09-15',
#   'Subject': '已成功取回您的 Google 帳戶',
#   'Sender': 'Google <no-reply@accounts.google.com>'},
#  {'msg_id': '18a97bc30cd26273',
#   'Date': '2023-09-15',
#   'Subject': '針對 jaytang9876@gmail.com 發出的安全性警示',
#   'Sender': 'Google <no-reply@accounts.google.com>'},
#  {'msg_id': '18a97bb6d0c88a01',
#   'Date': '2023-09-15',
#   'Subject': 'Google 驗證碼',
#   'Sender': 'Google <noreply@google.com>'},
#  {'msg_id': '18a975002cfa33d6',
#   'Sender': 'Steam <noreply@steampowered.com>',
#   'Subject': "Despot's Game: Dystopian Battle Simulator from your Steam wishlist is now on sale!",
#   'Date': '2023-09-14'},
#  {'msg_id': '18a973407052f291',
#   'Date': '2023-09-15',
#   'Sender': '"華南銀行" <service@ms3.hncb.com.tw>',
#   'Subject': '華南行動銀行APP登入成功通知'},
#  {'msg_id': '18a97232165d8373',
#   'Date': '2023-09-15',
#   'Sender': '"玉山銀行" <Service@info.esunbank.com>',
#   'Subject': 'e.Fingo會員權益及服務通知'},
#  {'msg_id': '18a96ccc5f530c91',
#   'Date': '2023-09-15',
#   'Sender': 'Fantia <noreply@fantia.jp>',
#   'Subject': '【Fantia】利用規約改定のご案内'},
#  {'msg_id': '18a9697f7ff5f9d7',
#   'Date': '2023-09-15',
#   'Subject': '針對 jaytang9876@gmail.com 發出的安全性警示',
#   'Sender': 'Google <no-reply@accounts.google.com>'},
#  {'msg_id': '18a964a8cf955301',
#   'Subject': '玉山銀行2023年08月信用卡電子帳單',
#   'Sender': '"玉山信用卡 " <estatement@esunbank.com>',
#   'Date': '2023-09-15'},
#  {'msg_id': '18a961564717e072',
#   'Date': '2023-09-14',
#   'Subject': 'Welcome to your Google Developer Profile!',
#   'Sender': 'Google Developer Profile <googledev-noreply@google.com>'},
#  {'msg_id': '18a9614517ab433c',
#   'Date': '2023-09-14',
#   'Subject': '安全性快訊',
#   'Sender': 'Google <no-reply@accounts.google.com>'},
#  {'msg_id': '18a960a755282356',
#   'Date': '2023-09-14',
#   'Subject': '免付費試用 YouTube Premium 2 個月',
#   'Sender': 'YouTube Premium <no-reply@youtube.com>'},
#  {'msg_id': '18a93880bacb13d8',
#   'Subject': '蝦皮店到店代收款繳款證明',
#   'Sender': '"蝦皮店到店" <stats.spx@shopee.com>',
#   'Date': '2023-09-14'},
#  {'msg_id': '18a8fdb40c20353a',
#   'Date': '2023-09-13',
#   'Subject': 'An update and a new chapter for Odysee',
#   'Sender': 'Odysee <email@mail.odysee.com>'},
#  {'msg_id': '18a8d2df2f88b638',
#   'Date': '2023-09-13',
#   'Sender': '"定錨產業筆記" <postmaster@mailer.investanchors.com>',
#   'Subject': '【定錨產業筆記】INTEL擬以台積電N3製程量產LUNAR LAKE'},
#  {'msg_id': '18a8679ac2b02cbe',
#   'Date': '2023-09-11',
#   'Sender': 'Firstrade Securities <service@firstrade.com>',
#   'Subject': '為您的賬戶啟用雙重身份驗證（2FA）'},
#  {'msg_id': '18a85b11bc65c5c3',
#   'Date': '2023-09-12',
#   'Sender': '"集保e手掌握" <epassbook@tdcc.com.tw>',
#   'Subject': '【集保】「集保e手掌握」App新增以電子方式接收股利發放通知功能，請貴客戶儘速完成eNotice(股務事務電子通知服務)申請！(若已知悉，請忽略此信件)'},
#  {'msg_id': '18a8469de40491c8',
#   'Date': '2023-09-11',
#   'Sender': '"定錨產業筆記" <postmaster@mailer.investanchors.com>',
#   'Subject': '【定錨產業筆記】聯亞(3081)：營運簡評'},
#  {'msg_id': '18a840441c3a86aa',
#   'Date': '2023-09-11',
#   'Sender': '"定錨產業筆記" <postmaster@mailer.investanchors.com>',
#   'Subject': '【定錨產業筆記】博通(AVGO)：財報電話會議摘要'},
#  {'msg_id': '18a8400f73f18df5',
#   'Date': '2023-09-11',
#   'Sender': '"定錨產業筆記" <postmaster@mailer.investanchors.com>',
#   'Subject': '【定錨產業筆記】台股觀察週報 2023/9/10'},
#  {'msg_id': '18a77449cbdb706c',
#   'Sender': '"蝦皮購物" <info@mail.shopee.tw>',
#   'Subject': '您的貨到付款訂單#230909TP9HV1C3已被確認',
#   'Date': '2023-09-09'},
#  {'msg_id': '18a76a68a4acdc70',
#   'Date': '2023-09-09',
#   'Sender': '"台北富邦銀行" <service@bhu.taipeifubon.com.tw>',
#   'Subject': '台北富邦銀行2023年8月 銀行對帳單'},
#  {'msg_id': '18a6b0ff49a72c68',
#   'Date': '2023-09-06',
#   'Sender': 'einvoice@fia.gov.tw',
#   'Subject': '財政部電子發票整合服\u200b務平台-消費發票彙整通知，手機條碼:/MK**ROR(每期)'},
#  {'msg_id': '18a67f238f8ce028',
#   'Date': '2023-09-06',
#   'Sender': '"台北富邦行動銀行" <mbank@dfm.taipeifubon.com.tw>',
#   'Subject': '台北富邦行動銀行一般登入交易「成功」通知'},
#  {'msg_id': '18a5f58d7aa86fcf',
#   'Date': '2023-09-04',
#   'Sender': '"定錨產業筆記" <postmaster@mailer.investanchors.com>',
#   'Subject': '【定錨產業筆記】台股觀察週報 2023/9/3'},
#  {'msg_id': '18a551fbc3382fa9',
#   'Date': '2023-09-02',
#   'Sender': '"酷澎" <noreply@coupang.com>',
#   'Subject': '[酷澎] 您的個人資料已變更！'},
#  {'msg_id': '18a4fa69ee19a833',
#   'Date': '2023-09-01',
#   'Sender': '"104人力銀行" <jobbank@104.com.tw>',
#   'Subject': '【富智捷股份有限公司】發給您的【詢問意願】'},
#  {'msg_id': '18a44f98c861f642',
#   'Sender': '"Hahow - 好學校" <course-message@hahow.in>',
#   'Subject': '課程「動畫互動網頁程式入門 (HTML/CSS/JS)」發佈了一篇新公告「墨雨互動設計 課程月報 #4 - 轉吧轉吧圓餅圖 / 童趣與詩意」',
#   'Date': '2023-08-30'},
#  {'msg_id': '18a44b9a2aabfad8',
#   'Date': '2023-08-30',
#   'Sender': '"定錨產業筆記" <postmaster@mailer.investanchors.com>',
#   'Subject': '【定錨產業筆記】L40S可望填補低階AI運算市場'},
#  {'msg_id': '18a3c788acc4d83a',
#   'Sender': '"Morningstar.com" <donotreply@morningstar.com>',
#   'Subject': 'J.P. Morgan Asset Management: Free Access to Morningstar Fund Analyst Reports',
#   'Date': '2023-08-28'},
#  {'msg_id': '18a377a6ce5708ec',
#   'Date': '2023-08-27',
#   'Sender': '"定錨產業筆記" <postmaster@mailer.investanchors.com>',
#   'Subject': '【定錨產業筆記】英偉達(NVDA)：財報電話會議摘要'},
#  {'msg_id': '18a37789187c2f2d',
#   'Date': '2023-08-27',
#   'Sender': '"定錨產業筆記" <postmaster@mailer.investanchors.com>',
#   'Subject': '【定錨產業筆記】迅得(6438)：營運簡評'},
#  {'msg_id': '18a37767769b9868',
#   'Date': '2023-08-27',
#   'Sender': '"定錨產業筆記" <postmaster@mailer.investanchors.com>',
#   'Subject': '【定錨產業筆記】台股觀察週報 2023/8/27'},
#  {'msg_id': '18a330322ad11600',
#   'Sender': 'FTX Customer Support <support@ftx.com>',
#   'Subject': 'Important Notice Regarding Your FTX Account',
#   'Date': '2023-08-26'},
#  {'msg_id': '18a2cc886e56f77d',
#   'Date': '2023-08-25',
#   'Sender': 'Firstrade Securities <service@firstrade.com>',
#   'Subject': 'Top Options Trading Ideas for the Coming Week'},
#  {'msg_id': '18a2b02cd8c64e4a',
#   'Date': '2023-08-25',
#   'Sender': '"noticing@ra.kroll.com" <noticing@ra.kroll.com>',
#   'Subject': 'IMPORTANT – Notice of Kroll’s Security Incident Involving Claimant Data/Steps to Protect Yourself'},
#  {'msg_id': '18a29c7860ad5c65',
#   'Date': '2023-08-24',
#   'Sender': 'Firstrade Securities <service@firstrade.com>',
#   'Subject': '轉移資產到Firstrade，享補貼最高$250美元！'},
#  {'msg_id': '18a271e2dcc0d2f4',
#   'Date': '2023-08-24',
#   'Sender': '"定錨產業筆記" <postmaster@mailer.investanchors.com>',
#   'Subject': '【定錨產業筆記】會員專屬直播 2023-08：製造業南向趨勢更新'},
#  {'msg_id': '18a16a9c3ecf660a',
#   'Date': '2023-08-21',
#   'Sender': '"104人力銀行" <jobbank@104.com.tw>',
#   'Subject': '【欣興電子股份有限公司】發給您的【詢問意願】'},
#  {'msg_id': '18a160b379e2b708',
#   'Date': '2023-08-21',
#   'Sender': '"定錨產業筆記" <postmaster@mailer.investanchors.com>',
#   'Subject': '【定錨產業筆記】台股觀察週報 2023/8/20'},
#  {'msg_id': '18a0dfd493889892',
#   'Date': '2023-08-19',
#   'Sender': '"台北富邦行動銀行" <mbank@dfm.taipeifubon.com.tw>',
#   'Subject': '台北富邦行動銀行一般登入交易「成功」通知'},
#  {'msg_id': '189fc6fce12c302c',
#   'Date': '2023-08-16',
#   'Sender': '"定錨產業筆記" <postmaster@mailer.investanchors.com>',
#   'Subject': '【定錨產業筆記】順德(2351)：營運簡評'},
#  {'msg_id': '189f7baef904aec6',
#   'Date': '2023-08-15',
#   'Sender': '"定錨產業筆記" <postmaster@mailer.investanchors.com>',
#   'Subject': '【定錨產業筆記】台股觀察週報 2023/8/13 (內容勘誤)'},
#  {'msg_id': '189efec7dab72a60',
#   'Date': '2023-08-13',
#   'Sender': 'noreply.efiling@ra.kroll.com',
#   'Subject': 'Electronic Proof of Claim_3265-70-LBUDS-215085664[[CSALT#900807#CF]] between Kroll and Chieh-Tse Tang is Signed and Filed! Your confirmation ID is 3265-70-LBUDS-215085664.'},
#  {'msg_id': '189ef5db56d7ccdd',
#   'Date': '2023-08-13',
#   'Sender': '"財政部稅務入口網" <webmail@etax.nat.gov.tw>',
#   'Subject': '電子稅務文件案件結案通知'},
#  {'msg_id': '189ef5642c993f86',
#   'Date': '2023-08-13',
#   'Sender': '"定錨產業筆記" <postmaster@mailer.investanchors.com>',
#   'Subject': '【定錨產業筆記】蘋果(AAPL)：財報電話會議摘要'},
#  {'msg_id': '189ef553a0bd74d4',
#   'Date': '2023-08-13',
#   'Sender': '"定錨產業筆記" <postmaster@mailer.investanchors.com>',
#   'Subject': '【定錨產業筆記】高通(QCOM)：財報電話會議摘要'},
#  {'msg_id': '189ef5361a31271f',
#   'Date': '2023-08-13',
#   'Sender': '"定錨產業筆記" <postmaster@mailer.investanchors.com>',
#   'Subject': '【定錨產業筆記】台股觀察週報 2023/8/13'},
#  {'msg_id': '189ef51e0021acd8',
#   'Date': '2023-08-13',
#   'Sender': '"財政部稅務入口網" <webmail@etax.nat.gov.tw>',
#   'Subject': '電子稅務文件案件線上申辦案件成立'},
#  {'msg_id': '189ef5053e7ce032',
#   'Date': '2023-08-13',
#   'Sender': '"財政部稅務入口網" <webmail@etax.nat.gov.tw>',
#   'Subject': '請回填信件驗證碼'},
#  {'msg_id': '189ef4bdf7bc66d8',
#   'Sender': '"eservice@nhi.gov.tw" <eservice@nhi.gov.tw>',
#   'Date': '2023-08-13',
#   'Subject': '[衛生福利部中央健康保險署-健保卡網路服務註冊-重設註冊密碼認證信(National Health Insurance Administration Verification Letter for Re-setting Registration Password for the Online Services of the National Health Insurance Card)]'},
#  {'msg_id': '189ef1a2238c5a43',
#   'Date': '2023-08-13',
#   'Sender': 'einvoice@fia.gov.tw',
#   'Subject': '財政部電子發票整合服務平台 – 112年05-06月期雲端發票中獎獎金匯款成功通知'},
#  {'msg_id': '189e94a9f2c8d86d',
#   'Date': '2023-08-12',
#   'Sender': '"104人力銀行" <jobbank@104.com.tw>',
#   'Subject': '【萊泀股份有限公司】發給您的【詢問意願】'},
#  {'msg_id': '189e3e94bbd41fd2',
#   'Date': '2023-08-11',
#   'Sender': '"定錨產業筆記" <postmaster@mailer.investanchors.com>',
#   'Subject': '【定錨產業筆記】欣興(3037)：法說會報告 (內容勘誤)'},
#  {'msg_id': '189e34f6cd78e984',
#   'Date': '2023-08-10',
#   'Subject': '更新《閒置 Google 帳戶政策》',
#   'Sender': 'Google Accounts Team <no-reply@accounts.google.com>'},
#  {'msg_id': '189dedd698fa8a33',
#   'Date': '2023-08-10',
#   'Sender': '"台北富邦銀行" <service@bhu.taipeifubon.com.tw>',
#   'Subject': '台北富邦銀行2023年7月 銀行對帳單'},
#  {'msg_id': '189deaeaa06f26ee',
#   'Date': '2023-08-10',
#   'Sender': '"台北富邦行動銀行" <mbank@dfm.taipeifubon.com.tw>',
#   'Subject': '台北富邦銀行帳戶資訊匯出通知'},
#  {'msg_id': '189deae276b5b1d5',
#   'Date': '2023-08-10',
#   'Sender': '"台北富邦行動銀行" <mbank@dfm.taipeifubon.com.tw>',
#   'Subject': '台北富邦行動銀行一般登入交易「失敗」通知'},
#  {'msg_id': '189d400bc2e17a20',
#   'Date': '2023-08-08',
#   'Sender': 'JIMTOF Fair Management Office ML <info_ml@jimtof.org>',
#   'Subject': 'JIMTOF 2024 will be held in November next year！／Japan Aerospace 2024 exhibitor application is open!'},
#  {'msg_id': '189cb9a97457bbaf',
#   'Date': '2023-08-06',
#   'Sender': '"定錨產業筆記" <postmaster@mailer.investanchors.com>',
#   'Subject': '【定錨產業筆記】台股觀察週報 2023/8/6'},
#  {'msg_id': '189cb29801ef58ba',
#   'Date': '2023-08-06',
#   'Sender': '"台北富邦行動銀行" <mbank@dfm.taipeifubon.com.tw>',
#   'Subject': '台北富邦銀行帳戶資訊匯出通知'},
#  {'msg_id': '189cb271a13dec90',
#   'Date': '2023-08-06',
#   'Sender': '"台北富邦行動銀行" <mbank@dfm.taipeifubon.com.tw>',
#   'Subject': '台北富邦行動銀行一般登入交易「成功」通知'},
#  {'msg_id': '189c98fa4030af6c',
#   'Sender': '"TAAZE 讀冊生活" <Marketing@edm.taaze.tw>',
#   'Subject': 'TAAZE讀冊生活創辦人給會員的信',
#   'Date': '2023-08-06'},
#  {'msg_id': '189c108dbaebd444',
#   'Date': '2023-08-04',
#   'Sender': '"定錨產業筆記" <postmaster@mailer.investanchors.com>',
#   'Subject': '【定錨產業筆記】欣興(3037)：法說會報告 (內容勘誤)'},
#  {'msg_id': '189bfb232bd3ab5f',
#   'Date': '2023-08-04',
#   'Sender': '"定錨產業筆記" <postmaster@mailer.investanchors.com>',
#   'Subject': '【定錨產業筆記】聯發科(2454)：法說會報告'},
#  {'msg_id': '189bfa464687b6ce',
#   'Date': '2023-08-04',
#   'Sender': '"定錨產業筆記" <postmaster@mailer.investanchors.com>',
#   'Subject': '【定錨產業筆記】英特爾(INTC)：財報電話會議摘要'},
#  {'msg_id': '189b92f809605227',
#   'Sender': '"蝦皮購物" <info@shopee.tw>',
#   'Subject': '您的蝦皮購物訂單#230723QTDNQ8XV 即將撥款賣家',
#   'Date': '2023-08-03'},
#  {'msg_id': '189b4b6399b49f58',
#   'Date': '2023-08-02',
#   'Sender': 'Fantia <noreply@fantia.jp>',
#   'Subject': '【お知らせ】規約変更のお知らせ'},
#  {'msg_id': '189b1a1688abab70',
#   'Date': '2023-08-02',
#   'Sender': 'Nissin Manufacturing <mktg@go.nissin-mfg.co.jp>',
#   'Subject': 'Announcing Nissin’s Comprehensive Honing Machine Portal'},
#  {'msg_id': '189b18db2038d1a5',
#   'Date': '2023-08-01',
#   'Sender': '"104人力銀行" <jobbank@104.com.tw>',
#   'Subject': '【矽果科技股份有限公司】發給您的【詢問意願】'},
#  {'msg_id': '189b022c6b629133',
#   'Date': '2023-08-01',
#   'Sender': '"定錨產業筆記" <postmaster@mailer.investanchors.com>',
#   'Subject': '【定錨產業筆記】會員專屬直播 2023-07：市場結構改變對投資人行為的影響 內容筆記'},
#  {'msg_id': '189aea0895fa6837',
#   'Sender': '"玉山銀行" <WebAlert@email.esunbank.com.tw>',
#   'Date': '2023-08-01',
#   'Subject': '玉山銀行開放銀行業務月彙整通知信件'},
#  {'msg_id': '189ae2df63571557',
#   'Date': '2023-07-31',
#   'Subject': 'Fellowships and Degrees from Johns Hopkins University',
#   'Sender': 'Johns Hopkins University <no-reply@m.mail.coursera.org>'},
#  {'msg_id': '189ab77067b7f041',
#   'Date': '2023-07-31',
#   'Sender': '"104人力銀行" <jobbank@104.com.tw>',
#   'Subject': '【奕力科技股份有限公司】發給您的【詢問意願】'},
#  {'msg_id': '189a9d3b4c6f642d',
#   'Date': '2023-07-31',
#   'Sender': '"定錨產業筆記" <postmaster@mailer.investanchors.com>',
#   'Subject': '【定錨產業筆記】台股觀察週報 2023/7/30'},
#  {'msg_id': '189a9849c01d266f',
#   'Sender': '"Hahow - 好學校" <course-message@hahow.in>',
#   'Subject': '課程「動畫互動網頁程式入門 (HTML/CSS/JS)」發佈了一篇新公告「墨雨互動設計 課程月報 #3 - CSS Grid 小介紹 / 有趣的 404 們」',
#   'Date': '2023-07-31'},
#  {'msg_id': '189a2727c25f5a6c',
#   'Date': '2023-07-30',
#   'Sender': 'einvoice@fia.gov.tw',
#   'Subject': '財政部電子發票整合服務平台 – 112年05-06月期雲端發票中獎通知'},
#  {'msg_id': '189a134b6d9b2884',
#   'Date': '2023-07-29',
#   'Sender': 'FTX <no-reply@sumsub.com>',
#   'Subject': 'FTX - Reminder to complete KYC submission'},
#  {'msg_id': '1899ef1ea0ebdda9',
#   'Date': '2023-07-28',
#   'Subject': '你的订阅预览已经结束',
#   'Sender': 'Strava <mail@update.strava.com>'},
#  {'msg_id': '1899d37fa4582e7a',
#   'Date': '2023-07-28',
#   'Sender': '"定錨產業筆記" <postmaster@mailer.investanchors.com>',
#   'Subject': '【定錨產業筆記】會員專屬直播 2023-07：市場結構改變對投資人行為的影響 (更新提問表單)'},
#  {'msg_id': '1899c8239d5a5aca',
#   'Date': '2023-07-28',
#   'Sender': '"定錨產業筆記" <postmaster@mailer.investanchors.com>',
#   'Subject': '【定錨產業筆記】特斯拉(TSLA)：財報電話會議摘要'},
#  {'msg_id': '1899ae28e05e98b9',
#   'Date': '2023-07-28',
#   'Sender': '"台北富邦銀行" <service@mhu.taipeifubon.com.tw>',
#   'Subject': '提醒您本期信用卡帳單繳款截止日快到囉 !'},
#  {'msg_id': '1899ad35e278aa4d',
#   'Date': '2023-07-28',
#   'Sender': '"定錨產業筆記" <postmaster@mailer.investanchors.com>',
#   'Subject': '【定錨產業筆記】欣興(3037)：法說會報告'},
#  {'msg_id': '1899a64853fcf777',
#   'Date': '2023-07-28',
#   'Sender': '"定錨產業筆記" <postmaster@mailer.investanchors.com>',
#   'Subject': '【定錨產業筆記】台燿(6274)：營運簡評'},
#  {'msg_id': '18996ef09633d4be',
#   'Date': '2023-07-27',
#   'Sender': '"定錨產業筆記" <postmaster@mailer.investanchors.com>',
#   'Subject': '【定錨產業筆記】台燿(6274)：營運簡評'},
#  {'msg_id': '18990e8e9ebbb59c',
#   'Date': '2023-07-26',
#   'Sender': '"104人力銀行" <jobbank@104.com.tw>',
#   'Subject': '【系統電子工業股份有限公司】發給您的【詢問意願】'},
#  {'msg_id': '189905bf3ead0204',
#   'Date': '2023-07-26',
#   'Sender': '"momo購物網" <service@momoshop.com.tw>',
#   'Subject': '【momo幣到期通知】親愛的*傑*您好，提醒您帳戶中momo幣將於07/29 23:59到期，請盡快使用'},
#  {'msg_id': '1898fb5d6b3869df',
#   'Date': '2023-07-26',
#   'Subject': '剩下 2 天时间，你可以充分利用你的免费预览',
#   'Sender': 'Strava <mail@update.strava.com>'},
#  {'msg_id': '1898f629f5bce6ab',
#   'Date': '2023-07-25',
#   'Sender': 'Twitter <verify@twitter.com>',
#   'Subject': '有從 Android 上的 9.98.0 登入 Twitter 的新活動'},
#  {'msg_id': '1898b0b6c2f14c7f',
#   'Date': '2023-07-25',
#   'Sender': '"定錨產業筆記" <postmaster@mailer.investanchors.com>',
#   'Subject': '【定錨產業筆記】RE100推動綠電儲能市場蓬勃發展 (2023/7/25更新)'},
#  {'msg_id': '1898908be7f3ae65',
#   'Date': '2023-07-25',
#   'Sender': '"新加坡商蝦皮娛樂電商有限公司台灣分公司" <b2ceci@ecimail2.tradevan.com.tw>',
#   'Subject': '新加坡商蝦皮娛樂電商有限公司台灣分公司電子發票開立通知'}]

# %%
import pandas as pd
df=pd.DataFrame(final_list)
print(df.shape)
df
# Out:
# (100, 4)
#               msg_id        Date  \
# 0   18a9b7763ddf0aed  2023-09-15
# 1   18a9b673b09df092  2023-09-16
# 2   18a9b018a39a5849  2023-09-16
# 3   18a9933066bc15e1  2023-09-15
# 4   18a9925ecae4b8bc  2023-09-15
# ..               ...         ...
# 95  1898647ff955358a  2023-07-24
# 96  18985a6fa6433448  2023-07-24
# 97  1898359ddb1a0a48  2023-07-23
# 98  18982f8409a759f5  2023-07-23
# 99  18982f83f8f3f8aa  2023-07-23
#
#                                                Sender  \
# 0                               epassbook@tdcc.com.tw
# 1                  Apple <News@insideapple.apple.com>
# 2                  "玉山銀行" <Service@info.esunbank.com>
# 3                           "富果團隊" <service@fugle.tw>
# 4        Firstrade Securities <service@firstrade.com>
# ..                                                ...
# 95  "新加坡商蝦皮娛樂電商有限公司台灣分公司" <b2ceci@ecimail3.tradeva...
# 96                     "104人力銀行" <jobbank@104.com.tw>
# 97     "定錨產業筆記" <postmaster@mailer.investanchors.com>
# 98                            "蝦皮購物" <info@shopee.tw>
# 99                            "蝦皮購物" <info@shopee.tw>
#
#                                              Subject
# 0                                 集保e手掌握銀行資訊更新次數彙整通知
# 1               <AD> 立即預訂 iPhone 15 Pro 與 iPhone 15。
# 2                                     玉山網路銀行每日帳務訊息通知
# 3             【課程即將上線】填問卷領 500 元課程折扣券，體驗會好評達 4.9 顆星🔥
# 4      Top Options Trading Ideas for the Coming Week
# ..                                               ...
# 95                       新加坡商蝦皮娛樂電商有限公司台灣分公司電子發票開立通知
# 96  【台達電子工業股份有限公司 _DELTA ELECTRONICS INC.】發給您的【詢問意願】
# 97                          【定錨產業筆記】台股觀察週報 2023/7/23
# 98                       您的貨到付款訂單#230723QTDNQ8XV已被確認
# 99                       您的貨到付款訂單#230723QTDNQ8XW已被確認
#
# [100 rows x 4 columns]

# %%
#result = df[df['Sender'].str.contains('shopee')]
keywords = ['linkedin', 
            #'shopee',
            #'104',
            'info@shopee.tw'
            'service@ms3.hncb.com.tw',
            'no-reply@accounts.google.com',
            '財經M平方',
            'epassbook@tdcc.com.tw', #集保中心
            'dailydozen@email.forbes.com',#富比世週報
            'account@seekingalpha.com',#seek alpha
            'billhunter@billhunter.kgieworld.com.tw',#凱基期貨
            'mail@mail.adobe.com',#adobe
            'edm@momo.com.tw',#momo廣告
            'alumni@nchu.edu.tw',#中興大學校友報馬仔
            'PERSOLKELLY',#推工作的
            '方格子',
            'noreply@medium.com'
           ]
pattern = '|'.join(keywords) 
result = df[df['Sender'].str.contains(pattern, case=False, regex=True)]
print(result.shape)
result
# Out:
# (8, 4)
#               msg_id        Date  \
# 0   18a9b7763ddf0aed  2023-09-15
# 5   18a98c823441b66b  2023-09-15
# 6   18a97bc314d50f9c  2023-09-15
# 7   18a97bc30cd26273  2023-09-15
# 12  18a9697f7ff5f9d7  2023-09-15
# 15  18a9614517ab433c  2023-09-14
# 21  18a85b11bc65c5c3  2023-09-12
# 57  189e34f6cd78e984  2023-08-10
#
#                                                Sender  \
# 0                               epassbook@tdcc.com.tw
# 5        "MacroMicro.me 財經M平方" <web@mg.macromicro.me>
# 6               Google <no-reply@accounts.google.com>
# 7               Google <no-reply@accounts.google.com>
# 12              Google <no-reply@accounts.google.com>
# 15              Google <no-reply@accounts.google.com>
# 21                   "集保e手掌握" <epassbook@tdcc.com.tw>
# 57  Google Accounts Team <no-reply@accounts.google...
#
#                                               Subject
# 0                                  集保e手掌握銀行資訊更新次數彙整通知
# 5                   【MM團隊來信】湯傑策，和你分享M平方里程碑，送上一份專屬禮物 🎁
# 6                                   已成功取回您的 Google 帳戶
# 7                   針對 jaytang9876@gmail.com 發出的安全性警示
# 12                  針對 jaytang9876@gmail.com 發出的安全性警示
# 15                                              安全性快訊
# 21  【集保】「集保e手掌握」App新增以電子方式接收股利發放通知功能，請貴客戶儘速完成eNoti...
# 57                                 更新《閒置 Google 帳戶政策》

# %%
for msg_id in result['msg_id']:
    #label_id = 'Notes'  # 不能用要找出對應Label_5
    #label_body = { "addLabelIds": ["UNREAD","Label_5"]}
    label_body = { "addLabelIds": ["Label_5"]}#python專屬
    #label_body =  {"removeLabelIds": ["UNREAD"]}
    print(msg_id)
    # 使用 Gmail API 添加標  
    msg = service.users().messages().modify(userId='me', id=msg_id, body=label_body).execute()
# Out:
# 18a9b7763ddf0aed
# 18a98c823441b66b
# 18a97bc314d50f9c
# 18a97bc30cd26273
# 18a9697f7ff5f9d7
# 18a9614517ab433c
# 18a85b11bc65c5c3
# 189e34f6cd78e984

# %%
keywords = ['驗證',
            '成功',
            '課程',
            '通知'
           ]
pattern = '|'.join(keywords)
result = df[df['Subject'].str.contains(pattern, case=False, regex=True)]
print(result.shape)
result
# Out:
# (24, 4)
#               msg_id        Date  \
# 0   18a9b7763ddf0aed  2023-09-15
# 2   18a9b018a39a5849  2023-09-16
# 3   18a9933066bc15e1  2023-09-15
# 6   18a97bc314d50f9c  2023-09-15
# 8   18a97bb6d0c88a01  2023-09-15
# 10  18a97232165d8373  2023-09-15
# 20  18a8679ac2b02cbe  2023-09-11
# 21  18a85b11bc65c5c3  2023-09-12
# 27  18a6b0ff49a72c68  2023-09-06
# 31  18a44f98c861f642  2023-08-30
# 47  189ef5db56d7ccdd  2023-08-13
# 52  189ef5053e7ce032  2023-08-13
# 54  189ef1a2238c5a43  2023-08-13
# 59  189deaeaa06f26ee  2023-08-10
# 60  189deae276b5b1d5  2023-08-10
# 63  189cb29801ef58ba  2023-08-06
# 72  189aea0895fa6837  2023-08-01
# 76  189a9849c01d266f  2023-07-31
# 77  189a2727c25f5a6c  2023-07-30
# 87  189905bf3ead0204  2023-07-26
# 91  1898908be7f3ae65  2023-07-25
# 93  189885845aeb65ec  2023-07-24
# 94  1898820fc100a3e0  2023-07-24
# 95  1898647ff955358a  2023-07-24
#
#                                                Sender  \
# 0                               epassbook@tdcc.com.tw
# 2                  "玉山銀行" <Service@info.esunbank.com>
# 3                           "富果團隊" <service@fugle.tw>
# 6               Google <no-reply@accounts.google.com>
# 8                         Google <noreply@google.com>
# 10                 "玉山銀行" <Service@info.esunbank.com>
# 20       Firstrade Securities <service@firstrade.com>
# 21                   "集保e手掌握" <epassbook@tdcc.com.tw>
# 27                                einvoice@fia.gov.tw
# 31            "Hahow - 好學校" <course-message@hahow.in>
# 47               "財政部稅務入口網" <webmail@etax.nat.gov.tw>
# 52               "財政部稅務入口網" <webmail@etax.nat.gov.tw>
# 54                                einvoice@fia.gov.tw
# 59          "台北富邦行動銀行" <mbank@dfm.taipeifubon.com.tw>
# 60          "台北富邦行動銀行" <mbank@dfm.taipeifubon.com.tw>
# 63          "台北富邦行動銀行" <mbank@dfm.taipeifubon.com.tw>
# 72            "玉山銀行" <WebAlert@email.esunbank.com.tw>
# 76            "Hahow - 好學校" <course-message@hahow.in>
# 77                                einvoice@fia.gov.tw
# 87                "momo購物網" <service@momoshop.com.tw>
# 91  "新加坡商蝦皮娛樂電商有限公司台灣分公司" <b2ceci@ecimail2.tradeva...
# 93                  Yahoo <no-reply@cc.yahoo-inc.com>
# 94                  Yahoo <no-reply@cc.yahoo-inc.com>
# 95  "新加坡商蝦皮娛樂電商有限公司台灣分公司" <b2ceci@ecimail3.tradeva...
#
#                                               Subject
# 0                                  集保e手掌握銀行資訊更新次數彙整通知
# 2                                      玉山網路銀行每日帳務訊息通知
# 3              【課程即將上線】填問卷領 500 元課程折扣券，體驗會好評達 4.9 顆星🔥
# 6                                   已成功取回您的 Google 帳戶
# 8                                          Google 驗證碼
# 10                                   e.Fingo會員權益及服務通知
# 20                                 為您的賬戶啟用雙重身份驗證（2FA）
# 21  【集保】「集保e手掌握」App新增以電子方式接收股利發放通知功能，請貴客戶儘速完成eNoti...
# 27          財政部電子發票整合服​務平台-消費發票彙整通知，手機條碼:/MK**ROR(每期)
# 31  課程「動畫互動網頁程式入門 (HTML/CSS/JS)」發佈了一篇新公告「墨雨互動設計 課程...
# 47                                       電子稅務文件案件結案通知
# 52                                           請回填信件驗證碼
# 54          財政部電子發票整合服務平台 – 112年05-06月期雲端發票中獎獎金匯款成功通知
# 59                                     台北富邦銀行帳戶資訊匯出通知
# 60                               台北富邦行動銀行一般登入交易「失敗」通知
# 63                                     台北富邦銀行帳戶資訊匯出通知
# 72                                  玉山銀行開放銀行業務月彙整通知信件
# 76  課程「動畫互動網頁程式入門 (HTML/CSS/JS)」發佈了一篇新公告「墨雨互動設計 課程...
# 77                財政部電子發票整合服務平台 – 112年05-06月期雲端發票中獎通知
# 87  【momo幣到期通知】親愛的*傑*您好，提醒您帳戶中momo幣將於07/29 23:59到期...
# 91                        新加坡商蝦皮娛樂電商有限公司台灣分公司電子發票開立通知
# 93                                  您的 Yahoo驗證碼為 WTBX
# 94                              您的 Yahoo驗證碼為 KJXCWRZP
# 95                        新加坡商蝦皮娛樂電商有限公司台灣分公司電子發票開立通知

# %%
for msg_id in result['msg_id']:
    label_body = { "addLabelIds": ["Label_5"]}#python專屬
    #label_body =  {"removeLabelIds": ["UNREAD"]}
    print(msg_id)
    # 使用 Gmail API 添加標  
    msg = service.users().messages().modify(userId='me', id=msg_id, body=label_body).execute()
# Out:
# 18a9b7763ddf0aed
# 18a9b6841a5e62a3
# 18a9b018a39a5849
# 18a9933066bc15e1
# 18a97bc314d50f9c
# 18a97bb6d0c88a01
# 18a973407052f291
# 18a97232165d8373
# 18a8679ac2b02cbe
# 18a85b11bc65c5c3
# 18a6b0ff49a72c68
# 18a67f238f8ce028
# 18a44f98c861f642
# 18a0dfd493889892
# 189ef5db56d7ccdd
# 189ef5053e7ce032
# 189ef1a2238c5a43
# 189deaeaa06f26ee
# 189deae276b5b1d5
# 189cb29801ef58ba
# 189cb271a13dec90
# 189aea0895fa6837
# 189a9849c01d266f
# 189a2727c25f5a6c
# 189905bf3ead0204
# 1898908be7f3ae65
